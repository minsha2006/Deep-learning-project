# %%
import torch
import torch.nn as nn
import torch.optim as optim

x = torch.unsqueeze(torch.linspace(-10, 10, 100), dim=1)
y = 3 * x - 2

model = nn.Linear(1, 1)

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 300
for epoch in range(epochs):
    y_pred = model(x)
    loss = criterion(y_pred, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 50 == 0:
        print(f"Epoch {epoch+1}, Loss: {loss.item()}")

test_input = torch.tensor([[10.0]])
prediction = model(test_input)

print("\nPrediction for x=10:", prediction.item())
# Out:
# Epoch 50, Loss: 0.8922283053398132
# Epoch 100, Loss: 0.11832686513662338
# Epoch 150, Loss: 0.01569240354001522
# Epoch 200, Loss: 0.0020811695139855146
# Epoch 250, Loss: 0.0002759958151727915
# Epoch 300, Loss: 3.660437505459413e-05
#
# Prediction for x=10: 28.005929946899414
